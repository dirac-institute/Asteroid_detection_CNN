# %%
repo="/repo/main"
coll="LSSTComCam/runs/DRP/DP1/w_2025_17/DM-50530"
where="instrument='LSSTComCam' AND skymap='lsst_cells_v1' AND day_obs>=20241101 AND day_obs<=20241127 AND exposure.observation_type='science' AND band in ('u','g','r','i','z','y') AND (exposure not in (2024110600163, 2024112400111, 2024110800318, 2024111200185, 2024111400039, 2024111500225, 2024111500226, 2024111500239, 2024111500240, 2024111500242, 2024111500288, 2024111500289, 2024111800077, 2024111800078, 2024112300230, 2024112400094, 2024112400225, 2024112600327))"

# %%
import pandas as pd
import numpy as np
from lsst.daf.butler import Butler
butler = Butler(repo, collections=coll)

# %%
refs = list(set(
        butler.registry.queryDatasets(
            "preliminary_visit_image",
            where=where,
            instrument="LSSTComCam",
            findFirst=True
        )
    ))

# %%
exp = butler.get("preliminary_visit_image", dataId=refs[0].dataId)

# %%
info = exp.getInfo()
info

# %%
exp.info.getSummaryStats()
# Out:
# ExposureSummaryStats(version=0, psfSigma=2.454423223064616, psfArea=96.87236941317013, psfIxx=5.6613868002947845, psfIyy=6.411500233003746, psfIxy=-0.08412595093191229, ra=52.60325884976096, dec=-28.16714543846084, pixelScale=0.20035312425943672, zenithDistance=16.25435907375646, expTime=30.0, zeroPoint=32.06564552235314, skyBg=463.9256896972656, skyNoise=24.417050016125202, meanVar=602.7544792626854, raCorners=[52.59850054968661, 52.783413136069605, 52.607973021478216, 52.422928296748815], decCorners=[-28.00840800902838, -28.165681939987902, -28.325882726857998, -28.168374722641527], astromOffsetMean=0.01585157107873738, astromOffsetStd=0.007976830870350423, nPsfStar=73, psfStarDeltaE1Median=-0.003003668040037221, psfStarDeltaE2Median=0.0008577860426157691, psfStarDeltaE1Scatter=0.012526588064537877, psfStarDeltaE2Scatter=0.008491781011054751, psfStarDeltaSizeMedian=0.003509344855931129, psfStarDeltaSizeScatter=0.020718474487920996, psfStarScaledDeltaSizeScatter=0.008425476408880314, psfTraceRadiusDelta=0.1534363486007262, psfApFluxDelta=0.003853406353946931, psfApCorrSigmaScaledDelta=0.0024944741657613252, maxDistToNearestPsf=788.6444374025484, effTime=10.267690884137, effTimePsfSigmaScale=0.44103830042365133, effTimeSkyBgScale=0.9990824183555271, effTimeZeroPointScale=0.7767368481630639, magLim=24.698399641633944)

# %%
m5 = exp.info.getSummaryStats().magLim

# %%
exp.getPhotoCalib().magnitudeToInstFlux(exp.info.getSummaryStats().magLim)/5
# Out:
# 176.98169410898677

# %%
import numpy as np
np.sqrt(np.median(exp.getVariance().array))
# Out:
# np.float32(24.513515)

# %%
dir(exp.getVariance())
# Out:
# ['Factory',
#  '__add__',
#  '__class__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__isub__',
#  '__itruediv__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '_get',
#  '_pybind11_conduit_v1_',
#  '_set',
#  'array',
#  'assign',
#  'clone',
#  'convertD',
#  'convertDouble',
#  'convertF',
#  'convertFloat',
#  'convertI',
#  'convertL',
#  'convertU',
#  'dtype',
#  'getArray',
#  'getBBox',
#  'getDimensions',
#  'getHeight',
#  'getWidth',
#  'getX0',
#  'getXY0',
#  'getY0',
#  'indexToPosition',
#  'positionToIndex',
#  'readFits',
#  'readFitsWithOptions',
#  'scaledDivides',
#  'scaledMinus',
#  'scaledMultiplies',
#  'scaledPlus',
#  'set',
#  'setXY0',
#  'sqrt',
#  'subset',
#  'writeFits',
#  'writeFitsWithOptions']
